# %%
print("hello world")

# %%
import math 
print(math.pi)
print(math.sqrt(2))

# %%
text = '나는 전역변수'
def say_hi(text):
    to_print = f"hi {text}"
    print(to_print)

say_hi("minwoo")
# Out:
# hi minwoo
